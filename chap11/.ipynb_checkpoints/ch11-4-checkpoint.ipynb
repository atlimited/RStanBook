# %%
import numpy as np
import pandas as pd
from scipy.stats import mstats
import matplotlib.pyplot as plt
import seaborn as sns
import pystan
# %matplotlib inline
plt.style.use("ggplot")

# %%
data = pd.read_csv('./input/data-mix2.txt')
data.head()
# Out:
#        Y
# 0   9.44
# 1   9.77
# 2  11.56
# 3  10.07
# 4  10.13

# %%
sns.distplot(data)

# %%
stan_model = """

data {
  int N;
  int K;
  vector[N] Y;
}

parameters {
  simplex[K] a;
  ordered[K] mu;
  vector<lower=0>[K] sigma;
  real<lower=0> s_mu;
}

model {
  mu ~ normal(mean(Y), s_mu);
  sigma ~ gamma(1.5, 1.0);
  for (n in 1:N){
    vector[K] lp;
    for (k in 1:K){
      lp[k] = log(a[k]) + normal_lpdf(Y[n] | mu[k], sigma[k]);
    }
    target += log_sum_exp(lp);
  }
}

"""

# %%
stan_model = """

functions {
  real normal_mixture_lpdf(real Y, int K, vector a, vector mu, vector sigma){
    vector[K] lp;
    for (k in 1:K){
      lp[k] = log(a[k]) + normal_lpdf(Y | mu[k], sigma[k]);
    }
    return log_sum_exp(lp);
  }
}

data {
  int N;
  int K;
  vector[N] Y;
}

parameters {
  simplex[K] a;
  ordered[K] mu;
  vector<lower=0>[K] sigma;
  real<lower=0> s_mu;
}

model {
  mu ~ normal(mean(Y), s_mu);
  sigma ~ gamma(1.5, 1.0);
  for (n in 1:N){
    Y[n] ~ normal_mixture(K, a, mu, sigma);
  }
}
"""

# %%
sm = pystan.StanModel(model_code=stan_model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9dd2e142277db981560d8f46884529c1 NOW.

# %%
stan_data = {}
stan_data['N'] = data.shape[0]
stan_data['K'] = 5
stan_data['Y'] = data['Y']

# %%
fit = sm.sampling(stan_data)

# %%
fit
# Out:
# Inference for Stan model: anon_model_9dd2e142277db981560d8f46884529c1.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#            mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# a[1]       0.17  4.4e-4   0.03   0.12   0.15   0.17   0.19   0.22   3391    1.0
# a[2]        0.1  9.5e-4   0.03   0.06   0.08    0.1   0.11   0.16    912    1.0
# a[3]       0.32  2.1e-3   0.07   0.18   0.27   0.32   0.37   0.46   1167    1.0
# a[4]       0.26  2.8e-3   0.08   0.11    0.2   0.26   0.32   0.42    828   1.01
# a[5]       0.15  1.8e-3   0.04   0.09   0.13   0.15   0.17   0.26    579   1.01
# mu[1]     10.01  3.1e-3   0.17   9.67    9.9  10.01  10.12  10.35   2997    1.0
# mu[2]     16.13    0.02    0.5   15.4  15.85  16.08  16.31  17.31    607    1.0
# mu[3]     20.88  2.9e-3   0.14  20.63  20.78  20.86  20.96   21.2   2308    1.0
# mu[4]     23.54    0.02   0.66  22.24  23.07  23.56  24.02  24.74   1022    1.0
# mu[5]     30.84    0.05    1.1  27.54   30.5  31.09  31.51  32.28    570   1.01
# sigma[1]   0.98  2.2e-3   0.13   0.77   0.89   0.97   1.05   1.28   3494    1.0
# sigma[2]   1.31    0.02   0.53   0.75   1.01   1.19   1.44    2.8    637    1.0
# sigma[3]   0.67  4.1e-3   0.15   0.42   0.56   0.65   0.76   1.01   1360    1.0
# sigma[4]   1.72    0.02    0.5   0.83   1.37   1.71   2.05   2.73   1075    1.0
# sigma[5]   2.69    0.03    0.7   1.78   2.22   2.53   2.98   4.67    767    1.0
# s_mu       9.91    0.11    4.8   4.64   6.84   8.62  11.44  21.89   1986    1.0
# lp__     -601.0    0.11   3.25 -608.7 -603.0 -600.6 -598.7 -596.0    954    1.0
#
# Samples were drawn using NUTS at Thu Apr 30 15:54:16 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
fig = fit.plot()
# Out:
# WARNING:pystan:Deprecation warning. PyStan plotting deprecated, use ArviZ library (Python 3.5+). `pip install arviz`; `arviz.plot_trace(fit)`)
