# %%
import numpy as np
import pandas as pd
from scipy.stats import mstats
import matplotlib.pyplot as plt
import seaborn as sns
import pystan
# %matplotlib inline
plt.style.use("ggplot")

# %%
data = pd.read_csv('./input/data-kubo11a.txt')
data.head()
# Out:
#    Y
# 0  0
# 1  3
# 2  2
# 3  5
# 4  6

# %%
sns.lineplot(data=data, x=data.index, y='Y')

# %%
stan_model = """

data {
  int I;
  int Y[I];
}

parameters {
  vector[I] r;
  real<lower=0> s_r;
}

model {
  target += normal_lpdf(r[2:I] | r[1:(I-1)], s_r);
  Y ~ poisson_log(r);
}

generated quantities {
  vector[I] Y_mean;
  Y_mean = exp(r);
}
"""

# %%
sm = pystan.StanModel(model_code=stan_model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_3093dd4c2da217841911f1abfbadc747 NOW.

# %%
stan_data = {}
stan_data['I'] = data.shape[0]
stan_data['Y'] = data['Y']

# %%
fit = sm.sampling(stan_data)

# %%
fit
# Out:
# WARNING:pystan:Truncated summary with the 'fit.__repr__' method. For the full summary use 'print(fit)'
# Warning: Shown data is truncated to 100 parameters
# For the full summary use 'print(fit)'
#
# Inference for Stan model: anon_model_3093dd4c2da217841911f1abfbadc747.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#              mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# r[1]         1.03  8.5e-3   0.37   0.22    0.8   1.06    1.3   1.67   1886    1.0
# r[2]          1.2  6.9e-3   0.31   0.54    1.0   1.22    1.4   1.77   1974    1.0
# r[3]         1.37  6.2e-3   0.27   0.77   1.21   1.39   1.56   1.85   1936    1.0
# r[4]         1.65  4.3e-3   0.23   1.17    1.5   1.66    1.8   2.07   2809    1.0
# r[5]         1.94  3.3e-3    0.2   1.54    1.8   1.94   2.07   2.32   3793    1.0
# r[6]         2.28  3.5e-3    0.2   1.91   2.15   2.27   2.41   2.69   3335    1.0
# r[7]          2.3  2.7e-3   0.19   1.94   2.18    2.3   2.42   2.67   4611    1.0
# r[8]         2.44  2.9e-3   0.18   2.09   2.32   2.44   2.56    2.8   3893    1.0
# r[9]         2.45  2.7e-3   0.18    2.1   2.34   2.45   2.57   2.79   4408    1.0
# r[10]        2.51  2.6e-3   0.18   2.16   2.39   2.51   2.63   2.84   4506    1.0
# r[11]         2.7  2.4e-3   0.17   2.37   2.59   2.71   2.82   3.02   4689    1.0
# r[12]         2.8  2.4e-3   0.16   2.48   2.69    2.8   2.91   3.11   4585    1.0
# r[13]        2.77  2.4e-3   0.16   2.44   2.66   2.77   2.88   3.08   4718    1.0
# r[14]        2.85  2.2e-3   0.16   2.53   2.75   2.85   2.95   3.16   5376    1.0
# r[15]        2.86  2.2e-3   0.16   2.56   2.76   2.86   2.96   3.17   5184    1.0
# r[16]        2.81  2.2e-3   0.16   2.49    2.7   2.81   2.92   3.12   5245    1.0
# r[17]         2.7  2.4e-3   0.17   2.37   2.59    2.7   2.81   3.01   4932    1.0
# r[18]         2.6  2.5e-3   0.17   2.26   2.49   2.61   2.71   2.92   4719    1.0
# Y_mean[27]  14.26    0.04   2.38  10.06  12.62  14.06   15.7  19.34   4269    1.0
# Y_mean[28]  14.29    0.04   2.41  10.08  12.65  14.13  15.78  19.58   4184    1.0
# Y_mean[29]  13.17    0.03    2.3   9.22  11.57  12.91  14.59  18.12   4591    1.0
# Y_mean[30]  10.93    0.03   2.02   7.32   9.56  10.81  12.18  15.13   3876    1.0
# Y_mean[31]  10.14    0.03   1.94   6.66    8.8   10.0   11.3  14.29   3437    1.0
# Y_mean[32]  11.69    0.03   2.15   7.97  10.16  11.51  12.94  16.41   4491    1.0
# Y_mean[33]  11.16    0.03   1.96   7.79   9.75  11.03  12.43  15.39   4386    1.0
# Y_mean[34]  11.37    0.03   2.02   7.84   9.94  11.21  12.62  15.74   4218    1.0
# Y_mean[35]  11.86    0.03   2.12    8.2  10.36   11.7  13.18   16.4   4830    1.0
# Y_mean[36]  10.89    0.03   1.98   7.39   9.53  10.75  12.16  15.11   3903    1.0
# Y_mean[37]  12.39    0.03   2.16   8.62  10.88  12.24  13.73  17.07   4466    1.0
# Y_mean[38]  12.97    0.03   2.28   9.06  11.37  12.77  14.34  17.97   4295    1.0
# Y_mean[39]  12.77    0.04   2.31   8.84  11.17  12.56  14.12  17.98   4079    1.0
# Y_mean[40]  12.52    0.04   2.31   8.68  10.88  12.29   13.9   17.7   3464    1.0
# Y_mean[41]   9.69    0.03   1.77   6.61   8.43   9.57  10.77  13.62   4128    1.0
# Y_mean[42]   8.28    0.03   1.57   5.56   7.17   8.18   9.27  11.68   3947    1.0
# Y_mean[43]   7.65    0.02   1.54   5.05   6.58   7.51   8.56  11.12   3827    1.0
# Y_mean[44]   6.18    0.02   1.33   3.89   5.22   6.06   7.03   9.08   3427    1.0
# Y_mean[45]   5.62    0.02   1.25   3.48   4.73   5.51   6.39   8.39   3299    1.0
# Y_mean[46]   5.26    0.02   1.18   3.23   4.45   5.18   5.96   7.86   3512    1.0
# Y_mean[47]   4.98    0.02   1.15    3.1   4.18   4.85   5.69   7.55   3274    1.0
# Y_mean[48]   4.24    0.02   1.05   2.46   3.49   4.14   4.87   6.67   2611    1.0
# lp__       807.08    0.35   8.97 788.74 801.25 807.28 813.32 823.71    648    1.0
#
# Samples were drawn using NUTS at Sat May  2 12:23:29 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
fig = fit.plot()
# Out:
# WARNING:pystan:Deprecation warning. PyStan plotting deprecated, use ArviZ library (Python 3.5+). `pip install arviz`; `arviz.plot_trace(fit)`)

# %%
sample_y_mean = fit.extract('Y_mean')['Y_mean']
lower80, upper80 = mstats.mquantiles(sample_y_mean, [0.1, 0.9], axis=0)
plt.scatter(data.index, data['Y'])
plt.fill_between(data.index, lower80, upper80, alpha=0.6, color='darkgray')
sns.lineplot(data=data, x=data.index, y='Y')

x = data.index
y = np.mean(sample_y_mean, axis=0)
plt.plot(x, y, color='black')
